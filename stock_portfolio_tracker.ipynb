# %%
# Stock Portfolio Tracker

# Predefined stock prices
stock_prices = {
    "AAPL": 180,
    "TSLA": 250,
    "GOOG": 2800,
    "AMZN": 3400,
    "MSFT": 300
}

total_investment = 0

print("Available stocks:", ", ".join(stock_prices.keys()))

while True:
    stock = input("\nEnter stock name (or 'done' to finish): ").upper()

    if stock == "DONE":
        break

    if stock in stock_prices:
        try:
            quantity = int(input(f"Enter quantity of {stock}: "))
        except ValueError:
            print(" Please enter a valid number!")
            continue

        value = stock_prices[stock] * quantity
        total_investment += value

        print(f" Added {stock}: ${value}")

    else:
        print(" Stock not found!")

# Final Output
print("\n==============================")
print(f" Total Investment Value: ${total_investment}")
print("==============================")

# Save result to file
with open("portfolio.txt", "w") as file:
    file.write(f"Total Investment Value: ${total_investment}")

print(" Result saved to 'portfolio.txt'")
# Out:
# Available stocks: AAPL, TSLA, GOOG, AMZN, MSFT
#
# Enter stock name (or 'done' to finish): AAPL
# Enter quantity of AAPL: 2
# ✅ Added AAPL: $360
#
# Enter stock name (or 'done' to finish): GOOG
# Enter quantity of GOOG: 3
# ✅ Added GOOG: $8400
#
# Enter stock name (or 'done' to finish): AMZN
# Enter quantity of AMZN: 100
# ✅ Added AMZN: $340000
#
# Enter stock name (or 'done' to finish): DONE
#
# ==============================
# 💰 Total Investment Value: $348760
# ==============================
# 📁 Result saved to 'portfolio.txt'
